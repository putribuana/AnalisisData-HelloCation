# %%
import re
import pandas as pd
from openpyxl import load_workbook
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %% [markdown]
# #Gathering Data Mentorship

# %% [markdown]
# ###Data Mentorship GKS U

# %%
dataset_gksu = ('/content/drive/MyDrive/Data Analyst HelloCation/Weekly 1 (Dataset MENTORSHIP)/mentorship-gksu.csv')

gks_u= pd.read_csv(dataset_gksu)
gks_u.head(5)
# Out:
#             Timestamp              Nama Lengkap          Asal Instansi  \
# 0  7/13/2023 21:11:01                      rima      sma thursina iibs
# 1  7/15/2023 17:37:03  Adriana Salsabila Irawan          SMAN 4 SUBANG
# 2  7/20/2023 22:27:03     Hernio Bayuaji Hutomo  Universitas Airlangga
# 3   7/21/2023 7:57:10           Willy Yudistira            SMAN 1 Maos
# 4  7/21/2023 18:38:45    YAYANG DIAZ ASTI PUTRI          SMKN 4 Malang
#
#                     Jurusan  \
# 0                       ips
# 1                       IPS
# 2                         -
# 3                       IPA
# 4  Rekayasa Perangkat Lunak
#
#                                             Domisili      Umur No. HP aktif  \
# 0                                             bekasi        19  82397070770
# 1  Buana Subang Kencana blok F64 RT.48 RW.16 Sokl...        18  87822380897
# 2                                               Palu        27  85713468183
# ...

# %% [markdown]
# ### Data Mentorship GKS G

# %%
dataset_gksg = ('/content/drive/MyDrive/Data Analyst HelloCation/Weekly 1 (Dataset MENTORSHIP)/mentorship-gksg.csv')

gks_g= pd.read_csv(dataset_gksg)
gks_g.head(5)
# Out:
#              Timestamp              Nama Lengkap                Asal Instansi  \
# 0  12/12/2022 21:25:50                 Nurhalija                 STIEM Palopo
# 1  04/01/2023 20:17:26  Mauliandini Nur Noviasri        Universitas Brawijaya
# 2  04/01/2023 21:01:02      Nabila Putri Candisa  Universitas Prasetiya Mulya
# 3  05/01/2023 14:02:34          Luchia Pri Utama           Universitas Bakrie
# 4  08/01/2023 22:46:41   Elisabet Suryani Wianto         Universitas Trisakti
#
#                         Jurusan   Domisili Umur No. HP aktif  \
# 0                     Akuntansi     Palopo   27  82264812346
# 1  Perencanaan Wilayah dan Kota    Jakarta   36  81908200974
# 2                     Marketing  Tangerang   28  85720368532
# 3        Hubungan Internasional    Jakarta   26  87766383553
# 4                     Akuntansi   Semarang   25  83838959450
#
#    Nama akun instagram                  Alasan ingin mengikuti mentorship  \
# ...

# %% [markdown]
# ###Data Mentorship GKS Sheet 3

# %%
dataset_gks_sheet = ('/content/drive/MyDrive/Data Analyst HelloCation/Weekly 1 (Dataset MENTORSHIP)/mentorship-sheet3.csv')

gks_sheet= pd.read_csv(dataset_gks_sheet)
gks_sheet.head(5)
# Out:
#              Timestamp                Nama Lengkap             Asal Instansi  \
# 0  29/07/2022 12:19:37                   Alexandra    SMK Analis Kimia Bogor
# 1  29/07/2022 19:19:32        Nia Veronica Agustin          Universitas Riau
# 2  30/07/2022 20:28:50              Fira Amalianda      President University
# 3  31/07/2022 12:51:54  Sajida Mustifa Radhianajla  SMAN 3 TANGERANG SELATAN
# 4  31/07/2022 22:19:55     Stephanie Candy Sabella                 SMA Pahoa
#
#                                   Jurusan                    Domisili Umur  \
# 0                Graduated (Analis Kimia)                       Bogor   19
# 1  Pendidikan Bahasa dan Sastra Indonesia              Pekanbaru kota   24
# 2                              Management  Kab.kuantan singingi, Riau   19
# 3                                     IPA           TANGERANG selatan   18
# 4                                     IPS                   Tangerang   18
#
#   No. HP aktif Nama akun instagram  \
# ...

# %% [markdown]
# #Assesing Data Mentorship

# %% [markdown]
# ###Tampilkan data mentorship-gksu

# %%
gks_u.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 15 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Timestamp                                            30 non-null     object
#  1   Nama Lengkap                                         30 non-null     object
#  2   Asal Instansi                                        30 non-null     object
#  3   Jurusan                                              30 non-null     object
#  4   Domisili                                             30 non-null     object
#  5   Umur                                                 30 non-null     object
#  6   No. HP aktif                                         30 non-null     object
#  7   Nama Acc Instagram                                   30 non-null     object
# ...

# %%
gks_g.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 10 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Timestamp                                  38 non-null     object
#  1   Nama Lengkap                               38 non-null     object
#  2   Asal Instansi                              38 non-null     object
#  3   Jurusan                                    38 non-null     object
#  4   Domisili                                   38 non-null     object
#  5   Umur                                       38 non-null     object
#  6   No. HP aktif                               38 non-null     object
#  7   Nama akun instagram                        38 non-null     object
#  8   Alasan ingin mengikuti mentorship          38 non-null     object
#  9   Pilih kelas Mentorship yang Anda inginkan  37 non-null     object
# ...

# %%
gks_sheet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 16 columns):
#  #   Column                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                          --------------  -----
#  0   Timestamp                                                                                       42 non-null     object
#  1   Nama Lengkap                                                                                    42 non-null     object
#  2   Asal Instansi                                                                                   42 non-null     object
#  3   Jurusan                                                                                         42 non-null     object
#  4   Domisili                                                                                        42 non-null     object
# ...

# %% [markdown]
# ###Cek missing value dan Hapus

# %%
gks_u.isna().sum()
# Out:
# Timestamp                                              0
# Nama Lengkap                                           0
# Asal Instansi                                          0
# Jurusan                                                0
# Domisili                                               0
# Umur                                                   0
# No. HP aktif                                           0
# Nama Acc Instagram                                     0
# Alasan mengikuti mentorship di Hellocation?            0
# Dari mana anda mengetahui informasi mentorship ini?    0
# Pilih kelas Mentorship yang Anda inginkan              0
# Beasiswa apa yang ingin diikuti?                       0
# Jenjang studi yang ingin di apply?                     0
# Rencana Univ yang dituju dan jurusan                   2
# Tanggal transfer                                       0
# dtype: int64

# %%
gks_g.isna().sum()
# Out:
# Timestamp                                    1
# Nama Lengkap                                 1
# Asal Instansi                                1
# Jurusan                                      1
# Domisili                                     1
# Umur                                         1
# No. HP aktif                                 1
# Nama akun instagram                          1
# Alasan ingin mengikuti mentorship            1
# Pilih kelas Mentorship yang Anda inginkan    2
# dtype: int64

# %%
gks_sheet.isna().sum()
# Out:
# Timestamp                                                                                          0
# Nama Lengkap                                                                                       0
# Asal Instansi                                                                                      0
# Jurusan                                                                                            0
# Domisili                                                                                           0
# Umur                                                                                               0
# No. HP aktif                                                                                       0
# Nama akun instagram                                                                                0
# Alasan ingin mengikuti mentorship                                                                  0
# ...

# %%
#hapus missing value
gks_u.dropna()
# Out:
#              Timestamp                                Nama Lengkap  \
# 2   7/20/2023 22:27:03                       Hernio Bayuaji Hutomo
# 3    7/21/2023 7:57:10                             Willy Yudistira
# 4   7/21/2023 18:38:45                      YAYANG DIAZ ASTI PUTRI
# 5   7/21/2023 20:48:07                    Ericha Veonetta Siswanto
# 6   7/22/2023 19:21:07                            SUCI AYU LESTARI
# 7   7/24/2023 13:56:24                                    Ya Putri
# 8    8/1/2023 18:05:41                      Farsya Maulida Wildani
# 9    8/1/2023 19:27:23                       Hanifati Azatil Ismah
# 10   8/7/2023 18:41:17       Qinthara Nazzala Oditha Puteri Liando
# 11  8/20/2023 18:59:14                 Salsabiela Vitasari Jasmine
# 12   8/21/2023 8:31:28                  Nasywa Nabila Nur Shabrina
# 13  8/24/2023 18:53:45                             Nikita Larasati
# 14  8/24/2023 18:54:31                        Deandra Annisa Putri
# ...

# %%
gks_g.dropna()
# Out:
#               Timestamp                 Nama Lengkap  \
# 1   04/01/2023 20:17:26     Mauliandini Nur Noviasri
# 2   04/01/2023 21:01:02         Nabila Putri Candisa
# 3   05/01/2023 14:02:34             Luchia Pri Utama
# 4   08/01/2023 22:46:41      Elisabet Suryani Wianto
# 5   12/01/2023 17:17:53          Luisa Tiara Purnomo
# 6   16/01/2023 20:14:00                Hasna Karimah
# 7   21/01/2023 18:15:20             Elfrida Dwiyanti
# 8   21/01/2023 21:33:58               Zulfahmi Sukma
# 9   22/01/2023 13:50:53                            -
# 10  24/01/2023 22:47:41         Putrini Andrea Zebua
# 11  25/01/2023 16:21:50       Nur Anisa Kurnia Putri
# 12  26/01/2023 10:59:40                  Sekar ratri
# 13  26/01/2023 17:07:22         Ervani Tri Wijayanti
# 14  28/01/2023 10:29:08             Nurti Hutagalung
# 15  28/01/2023 12:04:40                  Ismi Afifah
# 16  28/01/2023 16:29:15        Ulfiani Fauzia Hanafi
# 17  28/01/2023 16:58:22           Sari Intan Romauli
# ...

# %%
gks_sheet.dropna()
# Out:
# Empty DataFrame
# Columns: [Timestamp, Nama Lengkap, Asal Instansi, Jurusan, Domisili, Umur, No. HP aktif, Nama akun instagram, Alasan ingin mengikuti mentorship, Pilihan Kelas, Apakah kamu bersedia melakukan pembayaran sebesar Rp200.000 untuk kelas Reguler?, Apakah kamu bersedia menghadiri Onboarding yang akan dilaksanakan pada tanggal 6 Agustus 2022?, Apakah kamu bersedia mengikuti mentorship pada tanggal yang sudah ditentukan?, Unnamed: 13, Unnamed: 14, Unnamed: 15]
# Index: []

# %% [markdown]
# #Cek Dataset

# %%
gks_u.describe(include='all')
# Out:
#                  Timestamp Nama Lengkap          Asal Instansi Jurusan  \
# count                   30           30                     30      30
# unique                  30           30                     28      18
# top     7/13/2023 21:11:01         rima  Universitas Airlangga     IPA
# freq                     1            1                      2       7
#
#         Domisili Umur No. HP aktif Nama Acc Instagram  \
# count         30   30           30                 30
# unique        26   15           30                 30
# top     Surabaya   18  82397070770                  -
# freq           3    6            1                  1
#
#        Alasan mengikuti mentorship di Hellocation?  \
# count                                           30
# unique                                          30
# top                         mau persiapan ikut gks
# freq                                             1
#
#        Dari mana anda mengetahui informasi mentorship ini?  \
# ...

# %%
gks_g.describe(include='all')
# Out:
#                   Timestamp Nama Lengkap             Asal Instansi Jurusan  \
# count                    38           38                        38      38
# unique                   38           38                        35      28
# top     12/12/2022 21:25:50    Nurhalija  UPN “Veteran” Yogyakarta       -
# freq                      1            1                         2       6
#
#           Domisili Umur No. HP aktif Nama akun instagram  \
# count           38   38           38                  38
# unique          27   18           37                  36
# top     Yogyakarta   25  85720225369           kkulloves
# freq             5    7            2                   2
#
#                         Alasan ingin mengikuti mentorship  \
# count                                                  38
# unique                                                 38
# top     Ingin dibimbing dalam mempersiapkan diri utk m...
# freq                                                    1
#
# ...

# %%
gks_sheet.describe(include='all')
# Out:
#                   Timestamp Nama Lengkap           Asal Instansi Jurusan  \
# count                    42           42                      42      42
# unique                   42           42                      42      25
# top     29/07/2022 12:19:37    Alexandra  SMK Analis Kimia Bogor     IPA
# freq                      1            1                       1      10
# mean                    NaN          NaN                     NaN     NaN
# std                     NaN          NaN                     NaN     NaN
# min                     NaN          NaN                     NaN     NaN
# 25%                     NaN          NaN                     NaN     NaN
# 50%                     NaN          NaN                     NaN     NaN
# 75%                     NaN          NaN                     NaN     NaN
# max                     NaN          NaN                     NaN     NaN
#
#        Domisili Umur No. HP aktif Nama akun instagram  \
# ...

# %%
#cek data null
print('\nData Null GKS U:\n', gks_u.isnull().sum())
print('\nData Null GKS G:\n', gks_g.isnull().sum())
print('\nData Null GKS Sheet:\n', gks_sheet.isnull().sum())
# Out:
# Data Null GKS U:
#  Timestamp                                              0
# Nama Lengkap                                           0
# Asal Instansi                                          0
# Jurusan                                                0
# Domisili                                               0
# Umur                                                   0
# No. HP aktif                                           0
# Nama Acc Instagram                                     0
# Alasan mengikuti mentorship di Hellocation?            0
# Dari mana anda mengetahui informasi mentorship ini?    0
# Pilih kelas Mentorship yang Anda inginkan              0
# Beasiswa apa yang ingin diikuti?                       0
# Jenjang studi yang ingin di apply?                     0
# Rencana Univ yang dituju dan jurusan                   2
# Tanggal transfer                                       0
# dtype: int64
#
# Data Null GKS G:
#  Timestamp                                    1
# ...

# %%
#cek data duplikat
print('\nData Duplikat GKS U:\n', gks_u.duplicated().sum())
print('\nData Duplikat GKS G:\n', gks_g.duplicated().sum())
print('\nData Duplikat GKS Sheet:\n', gks_sheet.duplicated().sum())
# Out:
# Data Duplikat GKS U:
#  0
#
# Data Duplikat GKS G:
#  0
#
# Data Duplikat GKS Sheet:
#  0

# %% [markdown]
# #Cleaning Data

# %% [markdown]
# ###Ubah semua judul kolom jadi huruf kecil

# %%
# Ganti nama kolom menjadi huruf kecil dan bersambung, dan menghapus tanda tanya
gks_u.columns = [remove_question_marks(col.lower().replace(' ', '_')) for col in gks_u.columns]

kolom_yang_dihapus = 'judul_kolom_yang_sangat_panjang'
if kolom_yang_dihapus in gks_u.columns:
    gks_u.drop(columns=kolom_yang_dihapus, inplace=True)

def remove_question_marks_from_data(text):
    if isinstance(text, str):
        return re.sub(r'[?]', '', text)
    return text

gks_u.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 15 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   timestamp                                           30 non-null     object
#  1   nama_lengkap                                        30 non-null     object
#  2   asal_instansi                                       30 non-null     object
#  3   jurusan                                             30 non-null     object
#  4   domisili                                            30 non-null     object
#  5   umur                                                30 non-null     object
#  6   no._hp_aktif                                        30 non-null     object
#  7   nama_acc_instagram                                  30 non-null     object
# ...

# %%
# Ganti nama kolom menjadi huruf kecil dan bersambung, dan menghapus tanda tanya
gks_g.columns = [remove_question_marks(col.lower().replace(' ', '_')) for col in gks_g.columns]

kolom_yang_dihapus = 'judul_kolom_yang_sangat_panjang'
if kolom_yang_dihapus in gks_g.columns:
    gks_g.drop(columns=kolom_yang_dihapus, inplace=True)

def remove_question_marks_from_data(text):
    if isinstance(text, str):
        return re.sub(r'[?]', '', text)
    return text

gks_g.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 10 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   timestamp                                  38 non-null     object
#  1   nama_lengkap                               38 non-null     object
#  2   asal_instansi                              38 non-null     object
#  3   jurusan                                    38 non-null     object
#  4   domisili                                   38 non-null     object
#  5   umur                                       38 non-null     object
#  6   no._hp_aktif                               38 non-null     object
#  7   nama_akun_instagram                        38 non-null     object
#  8   alasan_ingin_mengikuti_mentorship          38 non-null     object
#  9   pilih_kelas_mentorship_yang_anda_inginkan  37 non-null     object
# ...

# %%
gks_sheet.columns = [remove_question_marks(col.lower().replace(' ', '_')) for col in gks_sheet.columns]

kolom_yang_dihapus = 'judul_kolom_yang_sangat_panjang'
if kolom_yang_dihapus in gks_sheet.columns:
    gks_sheet.drop(columns=kolom_yang_dihapus, inplace=True)

def remove_question_marks_from_data(text):
    if isinstance(text, str):
        return re.sub(r'[?]', '', text)
    return text

gks_sheet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 16 columns):
#  #   Column                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                         --------------  -----
#  0   timestamp                                                                                      42 non-null     object
#  1   nama_lengkap                                                                                   42 non-null     object
#  2   asal_instansi                                                                                  42 non-null     object
#  3   jurusan                                                                                        42 non-null     object
#  4   domisili                                                                                       42 non-null     object
# ...

# %%
gks_sheet = gks_sheet.drop(columns=['unnamed:_14'])
gks_sheet = gks_sheet.drop(columns=['unnamed:_15'])

# %%
gks_sheet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 13 columns):
#  #   Column                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                         --------------  -----
#  0   timestamp                                                                                      42 non-null     object
#  1   nama_lengkap                                                                                   42 non-null     object
#  2   asal_instansi                                                                                  42 non-null     object
#  3   jurusan                                                                                        42 non-null     object
#  4   domisili                                                                                       42 non-null     object
# ...

# %% [markdown]
# #EDA (Exploratory Data Analysis)

# %% [markdown]
# ##Explore gks_u

# %%
gks_u.sample(5)
# Out:
#              timestamp                           nama_lengkap  \
# 24  9/13/2023 23:43:44                  Irene Angelia Hartono
# 1   7/15/2023 17:37:03               Adriana Salsabila Irawan
# 21  9/13/2023 18:11:21                  Ranya Kayla Bilqisthi
# 5   7/21/2023 20:48:07               Ericha Veonetta Siswanto
# 10   8/7/2023 18:41:17  Qinthara Nazzala Oditha Puteri Liando
#
#                   asal_instansi        jurusan  \
# 24  Lulusan Smak Kesuma mataram    Lulusan IPA
# 1                 SMAN 4 SUBANG            IPS
# 21         SMKS Islamic Village  - (SMK - DKV)
# 5             SMAK Santo Paulus            IPS
# 10              SMAN 81 Jakarta            IPA
#
#                                              domisili umur no._hp_aktif  \
# 24                                           Surabaya   18  81805244210
# 1   Buana Subang Kencana blok F64 RT.48 RW.16 Sokl...   18  87822380897
# 21                                     Kota Tangerang   18  82112359623
# ...

# %%
gks_u.describe(include='all')
# Out:
#                  timestamp nama_lengkap          asal_instansi jurusan  \
# count                   30           30                     30      30
# unique                  30           30                     28      18
# top     7/13/2023 21:11:01         rima  Universitas Airlangga     IPA
# freq                     1            1                      2       7
#
#         domisili umur no._hp_aktif nama_acc_instagram  \
# count         30   30           30                 30
# unique        26   15           30                 30
# top     Surabaya   18  82397070770                  -
# freq           3    6            1                  1
#
#        alasan_mengikuti_mentorship_di_hellocation  \
# count                                          30
# unique                                         30
# top                        mau persiapan ikut gks
# freq                                            1
#
#        dari_mana_anda_mengetahui_informasi_mentorship_ini  \
# ...

# %%
gks_u.timestamp.is_unique
# Out:
# True

# %%
gks_u = gks_u.rename(columns={'no._hp_aktif': 'nomor_hp'})
gks_u = gks_u.rename(columns={'nama_acc_instagram': 'nama_ig'})
gks_u = gks_u.rename(columns={'alasan_mengikuti_mentorship_di_hellocation': 'alasan_join'})

gks_u = gks_u.rename(columns={'dari_mana_anda_mengetahui_informasi_mentorship_ini ': 'info_dari'})
gks_u = gks_u.rename(columns={'pilih_kelas_mentorship_yang_anda_inginkan': 'pilih_kelas'})
gks_u = gks_u.rename(columns={'beasiswa_apa_yang_ingin_diikuti': 'beasiswa_pilihan'})
gks_u = gks_u.rename(columns={'jenjang_studi_yang_ingin_di_apply': 'apply_study'})
gks_u = gks_u.rename(columns={'rencana_univ_yang_dituju_dan_jurusan': 'univ_tujuan'})

# %%
gks_u = gks_u.rename(columns={'dari_mana_anda_mengetahui_informasi_mentorship_ini': 'info_dari'})

gks_u.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   timestamp         30 non-null     object
#  1   nama_lengkap      30 non-null     object
#  2   asal_instansi     30 non-null     object
#  3   jurusan           30 non-null     object
#  4   domisili          30 non-null     object
#  5   umur              30 non-null     object
#  6   nomor_hp          30 non-null     object
#  7   nama_ig           30 non-null     object
#  8   alasan_join       30 non-null     object
#  9   info_dari         30 non-null     object
#  10  pilih_kelas       30 non-null     object
#  11  beasiswa_pilihan  30 non-null     object
#  12  apply_study       30 non-null     object
#  13  univ_tujuan       28 non-null     object
#  14  tanggal_transfer  30 non-null     object
# dtypes: object(15)
# memory usage: 3.6+ KB

# %%
gks_u["timestamp"] = pd.to_datetime(gks_u["timestamp"])

gks_u["nama_lengkap"] = gks_u["nama_lengkap"].str.title()

gks_u["asal_instansi"] = gks_u["asal_instansi"].str.title()
gks_u["asal_instansi"] = gks_u["asal_instansi"].str.replace("-", "", regex=False)
gks_u.dropna(subset=["asal_instansi"], inplace=True)

gks_u["jurusan"] = gks_u["jurusan"].str.replace("-", "", regex=False)
gks_u.dropna(subset=["jurusan"], inplace=True)

gks_u["umur"] = gks_u["umur"].astype(str)
gks_u["umur"] = gks_u["umur"].str.replace("T", " ")

gks_u["domisili"] = gks_u["domisili"].str.title()


gks_u["alasan_join"] = gks_u["alasan_join"].str.title()
gks_u["alasan_join"] = gks_u["alasan_join"].str.replace("-", "", regex=False)
gks_u.dropna(subset=["alasan_join"], inplace=True)

gks_u["info_dari"] = gks_u["info_dari"].str.title()
gks_u["info_dari"] = gks_u["info_dari"].str.replace("-", "", regex=False)
gks_u.dropna(subset=["info_dari"], inplace=True)

gks_u.loc[gks_u["pilih_kelas"] == 0, "pilih_kelas"] = "Kelas Private"
gks_u.loc[gks_u["pilih_kelas"] == 1, "pilih_kelas"] = "Kelas Reguler"

gks_u["tanggal_transfer"] = pd.to_datetime(gks_u["tanggal_transfer"])

# %%
gks_u.nama_lengkap.value_counts().sort_index()
# Out:
# Adriana Salsabila Irawan                      1
# Alifia Azzahra  +   Rimatul Ula               1
# Alinia Qkhan Dinie Syaputri                   1
# Amelia Wahyuningtyas                          1
# Deandra Annisa Putri                          1
# Ericha Veonetta Siswanto                      1
# Farsya Maulida Wildani                        1
# Finti                                         1
# Hanifati Azatil Ismah                         1
# Hasifa Zaysha Albany                          1
# Hernio Bayuaji Hutomo                         1
# Ignatius Loyola Revalino Chandra Kurniawan    1
# Indira Maia Banaati                           1
# Irene Angelia Hartono                         1
# Jennifer Sanjean                              1
# Joyce Audrey Jaya                             1
# Nasywa Nabila Nur Shabrina                    1
# Nikita Larasati                               1
# Nur Zahro                                     1
# Qinthara Nazzala Oditha Puteri Liando         1
# ...

# %%
gks_u["umur"] = gks_u["umur"].astype(str)
gks_u["umur"] = gks_u["umur"].str.replace("ahun", " ")

gks_u.umur.value_counts().sort_index()
# Out:
# 17       3
# 17       2
# 18       6
# 18       2
# 19       5
# 19       2
# 20       1
# 21       1
# 21       1
# 22       3
# 24       2
# 27       1
# 28       1
# Name: umur, dtype: int64

# %%
gks_u["umur"] = gks_u["umur"].astype(int)
gks_u.umur.value_counts().sort_index()
# Out:
# 17    5
# 18    8
# 19    7
# 20    1
# 21    2
# 22    3
# 24    2
# 27    1
# 28    1
# Name: umur, dtype: int64

# %%
gks_u.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   timestamp         30 non-null     datetime64[ns]
#  1   nama_lengkap      30 non-null     object
#  2   asal_instansi     30 non-null     object
#  3   jurusan           30 non-null     object
#  4   domisili          30 non-null     object
#  5   umur              30 non-null     int64
#  6   nomor_hp          30 non-null     object
#  7   nama_ig           30 non-null     object
#  8   alasan_join       30 non-null     object
#  9   info_dari         30 non-null     object
#  10  pilih_kelas       30 non-null     object
#  11  beasiswa_pilihan  30 non-null     object
#  12  apply_study       30 non-null     object
#  13  univ_tujuan       28 non-null     object
#  14  tanggal_transfer  30 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(12)
# ...

# %%
gks_u.to_csv('datacleaning_gksu.csv', index=False)

# %% [markdown]
# ##Explore gks_g

# %%
gks_g.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 10 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   timestamp                                  38 non-null     object
#  1   nama_lengkap                               38 non-null     object
#  2   asal_instansi                              38 non-null     object
#  3   jurusan                                    38 non-null     object
#  4   domisili                                   38 non-null     object
#  5   umur                                       38 non-null     object
#  6   no._hp_aktif                               38 non-null     object
#  7   nama_akun_instagram                        38 non-null     object
#  8   alasan_ingin_mengikuti_mentorship          38 non-null     object
#  9   pilih_kelas_mentorship_yang_anda_inginkan  37 non-null     object
# ...

# %%
gks_g = gks_g.rename(columns={'no._hp_aktif': 'nomor_hp'})
gks_g = gks_g.rename(columns={'nama_akun_instagram': 'nama_ig'})
gks_g = gks_g.rename(columns={'alasan_mengikuti_mentorship': 'alasan_join'})
gks_g = gks_g.rename(columns={'pilih_kelas_mentorship_yang_anda_inginkan': 'pilih_kelas'})

gks_g.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 10 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   timestamp                          38 non-null     object
#  1   nama_lengkap                       38 non-null     object
#  2   asal_instansi                      38 non-null     object
#  3   jurusan                            38 non-null     object
#  4   domisili                           38 non-null     object
#  5   umur                               38 non-null     object
#  6   nomor_hp                           38 non-null     object
#  7   nama_ig                            38 non-null     object
#  8   alasan_ingin_mengikuti_mentorship  38 non-null     object
#  9   pilih_kelas                        37 non-null     object
# dtypes: object(10)
# memory usage: 3.2+ KB

# %%
gks_g = gks_g.rename(columns={'alasan_ingin_mengikuti_mentorship': 'alasan_join'})

gks_g.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   timestamp      38 non-null     object
#  1   nama_lengkap   38 non-null     object
#  2   asal_instansi  38 non-null     object
#  3   jurusan        38 non-null     object
#  4   domisili       38 non-null     object
#  5   umur           38 non-null     object
#  6   nomor_hp       38 non-null     object
#  7   nama_ig        38 non-null     object
#  8   alasan_join    38 non-null     object
#  9   pilih_kelas    37 non-null     object
# dtypes: object(10)
# memory usage: 3.2+ KB

# %%
gks_g["timestamp"] = pd.to_datetime(gks_g["timestamp"])

gks_g["nama_lengkap"] = gks_g["nama_lengkap"].str.title()

gks_g["asal_instansi"] = gks_g["asal_instansi"].str.title()
gks_g["asal_instansi"] = gks_g["asal_instansi"].str.replace("-", "", regex=False)
gks_g.dropna(subset=["asal_instansi"], inplace=True)

gks_g["jurusan"] = gks_g["jurusan"].str.replace("-", "", regex=False)
gks_g.dropna(subset=["jurusan"], inplace=True)

gks_g["umur"] = gks_g["umur"].astype(str)
gks_g["umur"] = gks_g["umur"].str.replace("T", " ")

gks_g["domisili"] = gks_g["domisili"].str.title()

gks_g["alasan_join"] = gks_g["alasan_join"].str.replace("-", "", regex=False)
gks_g.dropna(subset=["alasan_join"], inplace=True)


gks_g.loc[gks_g["pilih_kelas"] == 0, "pilih_kelas"] = "Kelas Private"
gks_g.loc[gks_g["pilih_kelas"] == 1, "pilih_kelas"] = "Kelas Reguler"

# %%
gks_u["umur"] = gks_u["umur"].astype(str)
gks_u["umur"] = gks_u["umur"].str.replace("ahun", " ")

gks_u.umur.value_counts().sort_index()
# Out:
# 17    5
# 18    8
# 19    7
# 20    1
# 21    2
# 22    3
# 24    2
# 27    1
# 28    1
# Name: umur, dtype: int64

# %%
gks_g["umur"] = gks_u["umur"].astype(int)

gks_g.umur.value_counts().sort_index()
# Out:
# 17.0    5
# 18.0    7
# 19.0    7
# 20.0    1
# 21.0    2
# 22.0    3
# 24.0    2
# 27.0    1
# 28.0    1
# Name: umur, dtype: int64

# %%
gks_g.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38 entries, 0 to 38
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   timestamp      38 non-null     datetime64[ns]
#  1   nama_lengkap   38 non-null     object
#  2   asal_instansi  38 non-null     object
#  3   jurusan        38 non-null     object
#  4   domisili       38 non-null     object
#  5   umur           29 non-null     float64
#  6   nomor_hp       38 non-null     object
#  7   nama_ig        38 non-null     object
#  8   alasan_join    38 non-null     object
#  9   pilih_kelas    37 non-null     object
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 3.3+ KB

# %%
gks_g["umur"] = gks_u["umur"].astype(str)
gks_g.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38 entries, 0 to 38
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   timestamp      38 non-null     datetime64[ns]
#  1   nama_lengkap   38 non-null     object
#  2   asal_instansi  38 non-null     object
#  3   jurusan        38 non-null     object
#  4   domisili       38 non-null     object
#  5   umur           29 non-null     object
#  6   nomor_hp       38 non-null     object
#  7   nama_ig        38 non-null     object
#  8   alasan_join    38 non-null     object
#  9   pilih_kelas    37 non-null     object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 3.3+ KB

# %%
gks_g["umur"] = gks_u["umur"].astype(int)
gks_g.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38 entries, 0 to 38
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   timestamp      38 non-null     datetime64[ns]
#  1   nama_lengkap   38 non-null     object
#  2   asal_instansi  38 non-null     object
#  3   jurusan        38 non-null     object
#  4   domisili       38 non-null     object
#  5   umur           29 non-null     float64
#  6   nomor_hp       38 non-null     object
#  7   nama_ig        38 non-null     object
#  8   alasan_join    38 non-null     object
#  9   pilih_kelas    37 non-null     object
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 3.3+ KB

# %%
gks_g.sample(5)
# Out:
#              timestamp              nama_lengkap  \
# 24 2023-02-26 12:02:40             Aisyah Yasmin
# 38 2023-08-21 02:22:25   Karina Nathania Gunawan
# 30 2023-03-03 21:20:29       Januika Setiyawanti
# 29 2023-03-03 11:11:35  Yessica Ryanti Anggajaya
# 17 2023-01-28 16:58:22        Sari Intan Romauli
#
#                          asal_instansi           jurusan             domisili  \
# 24                   Telkom University     Design Produk    Tangerang Selatan
# 38  Universitas Widya Mandala Surabaya        Kedokteran  Jombang, Jawa Timur
# 30    Universitas Teknologi Yogyakarta       S1Akuntansi           Yogyakarta
# 29                 Universitas Mataram   Ilmu Komunikasi               Lombok
# 17               Universitas Mikroskil  Manajemen Bisnis                Medan
#
#     umur      nomor_hp              nama_ig  \
# 24  18.0   81212369655         yasmiinaisya
# 38   NaN   82234181771     @karina_nathania
# 30   NaN   81328108659  januika_setiyawanti
# ...

# %%
gks_g.to_csv('datacleaning_gksg.csv', index=False)

# %% [markdown]
# ##Explore gks_sheet

# %%
gks_sheet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 13 columns):
#  #   Column                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                         --------------  -----
#  0   timestamp                                                                                      42 non-null     object
#  1   nama_lengkap                                                                                   42 non-null     object
#  2   asal_instansi                                                                                  42 non-null     object
#  3   jurusan                                                                                        42 non-null     object
#  4   domisili                                                                                       42 non-null     object
# ...

# %%
gks_sheet = gks_sheet.drop(columns=['apakah_kamu_bersedia_melakukan_pembayaran_sebesar_rp200.000_untuk_kelas_reguler'])
gks_sheet = gks_sheet.drop(columns=['apakah_kamu_bersedia_menghadiri_onboarding_yang_akan_dilaksanakan_pada_tanggal_6_agustus_2022'])
gks_sheet = gks_sheet.drop(columns=['apakah_kamu_bersedia_mengikuti_mentorship_pada_tanggal_yang_sudah_ditentukan'])

gks_sheet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 10 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   timestamp                          42 non-null     object
#  1   nama_lengkap                       42 non-null     object
#  2   asal_instansi                      42 non-null     object
#  3   jurusan                            42 non-null     object
#  4   domisili                           42 non-null     object
#  5   umur                               42 non-null     object
#  6   no._hp_aktif                       42 non-null     object
#  7   nama_akun_instagram                42 non-null     object
#  8   alasan_ingin_mengikuti_mentorship  42 non-null     object
#  9   pilihan_kelas                      32 non-null     object
# dtypes: object(10)
# memory usage: 3.4+ KB

# %%
gks_sheet = gks_sheet.rename(columns={'no._hp_aktif': 'nomor_hp'})
gks_sheet = gks_sheet.rename(columns={'nama_akun_instagram': 'nama_ig'})
gks_sheet = gks_sheet.rename(columns={'alasan_ingin_mengikuti_mentorship': 'alasan_join'})

gks_sheet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   timestamp      42 non-null     object
#  1   nama_lengkap   42 non-null     object
#  2   asal_instansi  42 non-null     object
#  3   jurusan        42 non-null     object
#  4   domisili       42 non-null     object
#  5   umur           42 non-null     object
#  6   nomor_hp       42 non-null     object
#  7   nama_ig        42 non-null     object
#  8   alasan_join    42 non-null     object
#  9   pilihan_kelas  32 non-null     object
# dtypes: object(10)
# memory usage: 3.4+ KB

# %%
gks_sheet["timestamp"] = pd.to_datetime(gks_sheet["timestamp"])

gks_sheet["nama_lengkap"] = gks_sheet["nama_lengkap"].str.title()

gks_sheet["asal_instansi"] = gks_sheet["asal_instansi"].str.title()
gks_sheet["asal_instansi"] = gks_sheet["asal_instansi"].str.replace("-", "", regex=False)
gks_sheet.dropna(subset=["asal_instansi"], inplace=True)

gks_sheet["jurusan"] = gks_sheet["jurusan"].str.replace("-", "", regex=False)
gks_sheet.dropna(subset=["jurusan"], inplace=True)

gks_sheet["umur"] = gks_sheet["umur"].astype(str)
gks_sheet["umur"] = gks_sheet["umur"].str.replace("T", " ")

gks_sheet["domisili"] = gks_sheet["domisili"].str.title()

gks_sheet["alasan_join"] = gks_sheet["alasan_join"].str.replace("-", "", regex=False)
gks_sheet.dropna(subset=["alasan_join"], inplace=True)

# %%
gks_sheet["umur"] = gks_sheet["umur"].astype(str)
gks_sheet["umur"] = gks_sheet["umur"].str.replace("thn", " ")

# %%
gks_g["umur"] = gks_u["umur"].astype(int)

gks_g.umur.value_counts().sort_index()
# Out:
# 17.0    5
# 18.0    7
# 19.0    7
# 20.0    1
# 21.0    2
# 22.0    3
# 24.0    2
# 27.0    1
# 28.0    1
# Name: umur, dtype: int64

# %%
gks_sheet.sample(5)
# Out:
#              timestamp               nama_lengkap  \
# 27 2022-03-08 22:37:14     Ihsani Yaomi Al-Afgani
# 33 2022-04-08 16:20:40          Alfiana Yunike To
# 9  2022-01-08 18:41:06               Yenty Gustia
# 4  2022-07-31 22:19:55    Stephanie Candy Sabella
# 29 2022-03-08 23:21:21  Franky Sanjaya Galingging
#
#                    asal_instansi                    jurusan  \
# 27  Smkn 1 Cilimus (Sdg Bekerja)    Tata boga (sudah lulus)
# 33               Univ. Brawijaya
# 9            Universitas Terbuka  Pendidikan Bahasa Inggris
# 4                      Sma Pahoa                        IPS
# 29                      Gap Year                        IPA
#
#                                       domisili      umur     nomor_hp  \
# 27  Jawabarat (Skrg Sedang Bekerja Di Jakarta)        19  89512878169
# 33                                 Kota Malang  19 tahun  81259020660
# 9                                        Bogor        21  89647244748
# ...

# %%
gks_sheet.to_csv('datacleaning_gkssheet.csv', index=False)
